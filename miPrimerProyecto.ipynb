# %% [markdown]
# <a href="https://colab.research.google.com/github/florkmpz00-gith/Progralll-Semi-2026/blob/main/miPrimerProyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
